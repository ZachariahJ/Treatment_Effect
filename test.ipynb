# %%
from dataset import data_preprocessing

# %%
data = data_preprocessing()
# Out:
# Train/Val/Test Patients: 585/167/84
# Total Patients: 836
# ### SPLIT DONE ###

# %%
data.params["inverse_therapy_map"]
# Out:
# {0: 'D60-120',
#  1: 'DLX60QD',
#  2: 'V150-225',
#  3: 'V75-225',
#  4: 'VLX150QD',
#  5: 'VLX75QD'}
